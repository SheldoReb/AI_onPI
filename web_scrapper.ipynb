# %%
import autogen
# Out:
# c:\Users\Sheldon\Documents\GIT\AI_onPI\.venv\Lib\site-packages\flaml\__init__.py:20: UserWarning: flaml.automl is not available. Please install flaml[automl] to enable AutoML functionalities.
#   warnings.warn("flaml.automl is not available. Please install flaml[automl] to enable AutoML functionalities.")

# %%
config_path = "OAI_CONFIG_LIST"
config_list = autogen.config_list_from_json(
    config_path
) 
llm_config = {"temperature": 0, "config_list": config_list}

# %%
import os  # noqa: E402

bing_api_key = "5e9cc4c8260145ac8f4cfd2879eae685"

# %%
from autogen.agentchat.contrib.web_surfer import WebSurferAgent  # noqa: E402

web_surfer = WebSurferAgent(
    "web_surfer",
    llm_config=llm_config,
    summarizer_llm_config=llm_config,
    browser_config={"viewport_size": 4096, "bing_api_key": bing_api_key},
)

user_proxy = autogen.UserProxyAgent(
    "user_proxy",
    human_input_mode="NEVER",
    code_execution_config=False,
    default_auto_reply="",
    is_termination_msg=lambda x: True,
)

# %%
task1 = """Can you read this fully: https://developers.home-assistant.io/docs/api/rest/"""
user_proxy.initiate_chat(web_surfer, message=task1, clear_history=False)
# Out:
# user_proxy (to web_surfer):
#
# Can you read this fully: https://developers.home-assistant.io/docs/api/rest/
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> EXECUTING FUNCTION visit_page...
# web_surfer (to user_proxy):
#
# Address: https://developers.home-assistant.io/docs/api/rest/
# Title: REST API | Home Assistant Developer Docs
# Viewport position: Showing page 1 of 2.
# ...
# REST API | Home Assistant Developer Docs
#
# [Skip to main content](#__docusaurus_skipToContent_fallback)[![Home Assistant](/img/logo.svg)![Home Assistant](/img/logo.svg)**Developers**](/)[Home Assistant](#)
#
# * [Overview](/docs/architecture_index)
# * [Core](/docs/development_index)
# * [Frontend](/docs/frontend)
# * [Supervisor](/docs/supervisor)
# * [Add-ons](/docs/add-ons)
# * [Operating System](/docs/operating-system)
# * [Voice](/docs/voice/overview)
# * [Translations](/docs/translations)
# [Misc](/docs/misc)[Blog](/blog)
# ...

# %%
task2 = """Scroll down."""
user_proxy.initiate_chat(web_surfer, message=task2, clear_history=False)
# Out:
# user_proxy (to web_surfer):
#
# Scroll down.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> EXECUTING FUNCTION page_down...
# web_surfer (to user_proxy):
#
# Address: https://developers.home-assistant.io/docs/api/rest/
# Title: REST API | Home Assistant Developer Docs
# Viewport position: Showing page 2 of 2.
# ...
# get`/api/events`🔒
# get`/api/services`🔒
# get`/api/history/period/<timestamp>`🔒
# get`/api/logbook/<timestamp>`🔒
# get`/api/states`🔒
# get`/api/states/<entity_id>`🔒
# get`/api/error_log`🔒
# get`/api/camera_proxy/<camera entity_id>`🔒
# get`/api/calendars`🔒
# get`/api/calendars/<calendar entity_id>`🔒
# post`/api/states/<entity_id>`🔒
# post`/api/events/<event_type>`🔒
# post`/api/services/<domain>/<service>`🔒
# post`/api/template`🔒
# post`/api/config/core/check_config`🔒
# ...

# %%
task3 = """https:///docs/api/events"""
user_proxy.initiate_chat(web_surfer, message=task3, clear_history=False)
# Out:
# user_proxy (to web_surfer):
#
# https:///docs/api/events
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> EXECUTING FUNCTION navigational_web_search...
# web_surfer (to user_proxy):
#
# Error: 401 Client Error: Access Denied for url: https://api.bing.microsoft.com/v7.0/search?q=%2Fapi%2Fevents&textDecorations=False&textFormat=raw
#
# --------------------------------------------------------------------------------
# ...
